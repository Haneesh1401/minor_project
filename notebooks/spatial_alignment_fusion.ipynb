# %%
import numpy as np
import rasterio
from rasterio.warp import reproject, Resampling
import xarray as xr

# %%
ndvi_ref_path = "../data/ndvi_daily/ndvi_day_01.tif"

with rasterio.open(ndvi_ref_path) as ref:
    ndvi_crs = ref.crs
    ndvi_transform = ref.transform
    ndvi_shape = ref.shape

print("NDVI shape:", ndvi_shape)
print("NDVI CRS:", ndvi_crs)
# Out:
# NDVI shape: (10342, 12242)
# NDVI CRS: EPSG:4326

# %%
ndvi_stack = np.load("../data/ndvi_stack.npy")

print("NDVI stack shape:", ndvi_stack.shape)
# Out:
# NDVI stack shape: (14, 10342, 12242)

# %%
era5_path = "../data/era5_raw/era5_weather_si_20230101_20230114.nc"

ds = xr.open_dataset(era5_path)
ds = ds.rename({"valid_time": "time"})
ds_daily = ds.resample(time="1D").mean()

# %%
# Wind speed
ds_daily["wind_speed"] = np.sqrt(
    ds_daily["u10"]**2 + ds_daily["v10"]**2
)

# Relative Humidity
T = ds_daily["t2m"] - 273.15
Td = ds_daily["d2m"] - 273.15

es_T = 6.112 * np.exp((17.67 * T) / (T + 243.5))
es_Td = 6.112 * np.exp((17.67 * Td) / (Td + 243.5))

ds_daily["relative_humidity"] = 100 * (es_Td / es_T)

# %%
T_steps = ds_daily.dims["time"]
H, W = ndvi_shape

wind_aligned = np.zeros((T_steps, H, W), dtype=np.float32)
rh_aligned = np.zeros((T_steps, H, W), dtype=np.float32)
# Out:
# C:\Users\Haneesh.B\AppData\Local\Temp\ipykernel_35716\2169307018.py:1: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   T_steps = ds_daily.dims["time"]

# %%
for t in range(T_steps):
    wind_src = ds_daily["wind_speed"].isel(time=t).values
    rh_src = ds_daily["relative_humidity"].isel(time=t).values

    src_transform = rasterio.transform.from_bounds(
        float(ds.longitude.min()),
        float(ds.latitude.min()),
        float(ds.longitude.max()),
        float(ds.latitude.max()),
        wind_src.shape[1],
        wind_src.shape[0],
    )

    reproject(
        source=wind_src,
        destination=wind_aligned[t],
        src_transform=src_transform,
        src_crs="EPSG:4326",
        dst_transform=ndvi_transform,
        dst_crs=ndvi_crs,
        resampling=Resampling.bilinear
    )

    reproject(
        source=rh_src,
        destination=rh_aligned[t],
        src_transform=src_transform,
        src_crs="EPSG:4326",
        dst_transform=ndvi_transform,
        dst_crs=ndvi_crs,
        resampling=Resampling.bilinear
    )

    print(f"Aligned day {t+1}")
# Out:
# Aligned day 1
# Aligned day 2
# Aligned day 3
# Aligned day 4
# Aligned day 5
# Aligned day 6
# Aligned day 7
# Aligned day 8
# Aligned day 9
# Aligned day 10
# Aligned day 11
# Aligned day 12
# Aligned day 13
# Aligned day 14

# %%
wind_aligned = wind_aligned[..., np.newaxis]
rh_aligned = rh_aligned[..., np.newaxis]

print(wind_aligned.shape, rh_aligned.shape)
# Out:
# (14, 10342, 12242, 1) (14, 10342, 12242, 1)

# %%
# Ensure NDVI has channel dimension
if ndvi_stack.ndim == 3:
    ndvi_stack = ndvi_stack[..., np.newaxis]

# Ensure wind & RH have channel dimension
if wind_aligned.ndim == 3:
    wind_aligned = wind_aligned[..., np.newaxis]

if rh_aligned.ndim == 3:
    rh_aligned = rh_aligned[..., np.newaxis]

print("NDVI shape:", ndvi_stack.shape)
print("Wind shape:", wind_aligned.shape)
print("RH shape:", rh_aligned.shape)
# Out:
# NDVI shape: (14, 10342, 12242, 1)
# Wind shape: (14, 10342, 12242, 1)
# RH shape: (14, 10342, 12242, 1)

# %%
def downsample(arr, factor=4):
    return arr[:, ::factor, ::factor, :]

# Downsample each tensor
ndvi_ds = downsample(ndvi_stack, factor=4)
wind_ds = downsample(wind_aligned, factor=4)
rh_ds = downsample(rh_aligned, factor=4)

print(ndvi_ds.shape, wind_ds.shape, rh_ds.shape)
# Out:
# (14, 2586, 3061, 1) (14, 2586, 3061, 1) (14, 2586, 3061, 1)

# %%
final_input = np.concatenate(
    (ndvi_ds, wind_ds, rh_ds),
    axis=-1
)

print("Final ConvLSTM input shape:", final_input.shape)
# Out:
# Final ConvLSTM input shape: (14, 2586, 3061, 3)

# %%
np.save("../data/convlstm_input_ds.npy", final_input)
print("Downsampled ConvLSTM input saved successfully")
# Out:
# Downsampled ConvLSTM input saved successfully

# %%
# STEP 1.4 — Create Environmental Dust Cube (FINAL & REQUIRED)

import numpy as np
import os

# -----------------------------
# Load required inputs
# -----------------------------
ndvi_stack = np.load("../outputs/ndvi_stack.npy")
era5_wind = np.load("../outputs/era5_wind_features.npy")

print("NDVI stack shape:", ndvi_stack.shape)
print("ERA5 wind shape:", era5_wind.shape)

# -----------------------------
# Align time & space
# -----------------------------
T = min(ndvi_stack.shape[0], era5_wind.shape[0])
H = min(ndvi_stack.shape[1], era5_wind.shape[1])
W = min(ndvi_stack.shape[2], era5_wind.shape[2])

ndvi_aligned = ndvi_stack[:T, :H, :W]
wind_speed = era5_wind[:T, :H, :W, 0]
wind_direction = era5_wind[:T, :H, :W, 1]

print("Aligned NDVI shape:", ndvi_aligned.shape)
print("Aligned wind speed shape:", wind_speed.shape)

# -----------------------------
# Dust Activity Index (DAI)
# -----------------------------
dust_activity_index = (1.0 - ndvi_aligned) * wind_speed

# -----------------------------
# Final environmental cube
# Channels:
# 0 → NDVI
# 1 → Wind Speed
# 2 → Wind Direction
# 3 → Dust Activity Index
# -----------------------------
environmental_dust_cube = np.stack(
    [
        ndvi_aligned,
        wind_speed,
        wind_direction,
        dust_activity_index
    ],
    axis=-1
)

print("Environmental dust cube shape:", environmental_dust_cube.shape)

# -----------------------------
# Save output
# -----------------------------
os.makedirs("../outputs", exist_ok=True)
np.save("../outputs/environmental_dust_cube.npy", environmental_dust_cube)

print("✅ environmental_dust_cube.npy saved successfully")
# Out:
# NDVI stack shape: (14, 1293, 1531)
# ERA5 wind shape: (336, 721, 1440, 2)
# Aligned NDVI shape: (14, 721, 1440)
# Aligned wind speed shape: (14, 721, 1440)
# Environmental dust cube shape: (14, 721, 1440, 4)
# ✅ environmental_dust_cube.npy saved successfully

# %%
import os
print(os.listdir("../outputs"))
# Out:
# ['environmental_dust_cube.npy', 'era5_wind_features.npy', 'ndvi_stack.npy']
